# %% [markdown]
# <a href="https://colab.research.google.com/github/aluqbnle/ml-sandbox/blob/master/18_Recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 回帰

# %% [markdown]
# ## 特徴量

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
X = boston.data # 特徴量
y = boston.target # 目的変数
feature_names = boston.feature_names # 特徴量名

# %%
from pandas import DataFrame

df = DataFrame(data=X,columns=feature_names)
df['MEDV'] = y # 目的変数

# 不要なカラムを削除する
df.drop(columns=['CHAS','NOX','B'],inplace=True)

df.head() #上から5行を表示する
# Out:
#       CRIM    ZN  INDUS     RM   AGE     DIS  RAD    TAX  PTRATIO  LSTAT  MEDV
# 0  0.00632  18.0   2.31  6.575  65.2  4.0900  1.0  296.0     15.3   4.98  24.0
# 1  0.02731   0.0   7.07  6.421  78.9  4.9671  2.0  242.0     17.8   9.14  21.6
# 2  0.02729   0.0   7.07  7.185  61.1  4.9671  2.0  242.0     17.8   4.03  34.7
# 3  0.03237   0.0   2.18  6.998  45.8  6.0622  3.0  222.0     18.7   2.94  33.4
# 4  0.06905   0.0   2.18  7.147  54.2  6.0622  3.0  222.0     18.7   5.33  36.2

# %% [markdown]
# ## データの可視化

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS          RM         AGE         DIS  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    6.284634   68.574901    3.795043
# std      8.601545   23.322453    6.860353    0.702617   28.148861    2.105710
# min      0.006320    0.000000    0.460000    3.561000    2.900000    1.129600
# 25%      0.082045    0.000000    5.190000    5.885500   45.025000    2.100175
# 50%      0.256510    0.000000    9.690000    6.208500   77.500000    3.207450
# 75%      3.677083   12.500000   18.100000    6.623500   94.075000    5.188425
# max     88.976200  100.000000   27.740000    8.780000  100.000000   12.126500
#
#               RAD         TAX     PTRATIO       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     9.549407  408.237154   18.455534   12.653063   22.532806
# std      8.707259  168.537116    2.164946    7.141062    9.197104
# ...

# %%
from matplotlib import pyplot
#pyplot.rcParams['font.family']='IPAGothic'
from pandas.plotting import scatter_matrix

# %%
# 散布図の描画
cols = ['CRIM', 'RM', 'TAX', 'DIS', 'LSTAT', 'MEDV']
axes = scatter_matrix(df[cols], figsize=(15, 15))
